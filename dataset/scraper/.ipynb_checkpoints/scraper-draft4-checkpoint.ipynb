# %% [markdown]
# ## MoonBoard 2016-2017
#
# * note: for 2016, uncomment pages 8-9-10-11-12

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import time

# %%
# login

web = "https://www.moonboard.com/"
path = "C:/Users//mertt/Desktop/udemy/Scraping/chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get(web)
driver.maximize_window()

login = driver.find_element_by_xpath('//*[@id="loginDropdown"]')
login.click()

time.sleep(1)
    
username = driver.find_element_by_xpath('//*[@id="Login_Username"]')
username.send_keys("amigocipis")

time.sleep(1)

password = driver.find_element_by_xpath('//*[@id="Login_Password"]')
password.send_keys("f5ais*Er")

time.sleep(1)

login_button = driver.find_element_by_xpath('//*[@id="navlogin"]')
login_button.click()

time.sleep(5)


# select moonboard 2019

 #2020 value 19
 #2019 value = 17
 #2017 value = 15
 #2016 value = 1

moonboard2019 = Select(driver.find_element_by_id('Holdsetup'))
moonboard2019.select_by_value('17')

time.sleep(15)


# page 1


containers = driver.find_elements_by_xpath("//*[@class='k-grid-content k-auto-scrollable']")
routes = containers[1].find_elements_by_xpath('.//a')
time.sleep(5)



for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page1.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])

# page2

page_2 = driver.find_elements_by_xpath("//*[@data-page='2']")[1]
page_2.click()
time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page2.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    
   
# page3

page_3 = driver.find_elements_by_xpath("//*[@data-page='3']")[1]
page_3.click()
time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page3.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
        
# page 4

page_4 = driver.find_elements_by_xpath("//*[@data-page='4']")[1]
page_4.click()
time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page4.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
        
## page 5

page_5 = driver.find_elements_by_xpath("//*[@data-page='5']")[1]
page_5.click()
time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page5.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
                
# page 6

page_6 = driver.find_elements_by_xpath("//*[@data-page='6']")[1]
page_6.click()
time.sleep(5)
print("6 clicked")

containers = driver.find_elements_by_xpath("//*[@class='k-grid-content k-auto-scrollable']")
routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page6.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
    

                
# page 7

print("start of 7")
containers = driver.find_elements_by_xpath("//*[@class='k-grid-content k-auto-scrollable']")
routes = containers[1].find_elements_by_xpath('.//a')

page_7 = driver.find_elements_by_xpath("//*[@data-page='7']")[0]
page_7.click()
print("clicked?")

containers = driver.find_elements_by_xpath("//*[@class='k-grid-content k-auto-scrollable']")
routes = containers[1].find_elements_by_xpath('.//a')

time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page7.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])           
    
# page 8

page_8 = driver.find_elements_by_xpath("//*[@data-page='8']")[0]
page_8.click()
time.sleep(5)

routes = containers[1].find_elements_by_xpath('.//a')

for route in routes:
    route.click()
    driver.switch_to.window(driver.window_handles[-1])
    pageSource = driver.page_source
    with open("./moonboard2019-scraped-files/page8.txt", "a", encoding="utf-8") as f:
        f.write(pageSource)
        f.close
    driver.close()
    driver.switch_to.window(driver.window_handles[0])                  

## page 9
#
#page_9 = driver.find_element_by_xpath("//*[@data-page='9']")[0]
#page_9.click()
#time.sleep(2)
#
#routes = containers[1].find_elements_by_xpath('.//a')
#
#for route in routes:
#    route.click()
#    driver.switch_to.window(driver.window_handles[-1])
#    pageSource = driver.page_source
#    with open("page9.txt", "a", encoding="utf-8") as f:
#        f.write(pageSource)
#        f.close
#    driver.close()
#    driver.switch_to.window(driver.window_handles[0])  
#
#    
## page 10
#
#page_10 = driver.find_element_by_xpath("//*[@data-page='10']")[0]
#page_10.click()
#time.sleep(2)
#
#routes = containers[1].find_elements_by_xpath('.//a')
#
#for route in routes:
#    route.click()
#    driver.switch_to.window(driver.window_handles[-1])
#    pageSource = driver.page_source
#    with open("page10.txt", "a", encoding="utf-8") as f:
#        f.write(pageSource)
#        f.close
#    driver.close()
#    driver.switch_to.window(driver.window_handles[0])  
#
#
## page 11
#
#page_11 = driver.find_element_by_xpath("//*[@data-page='11']")[0]
#page_11.click()
#time.sleep(2)
#
#routes = containers[1].find_elements_by_xpath('.//a')
#
#for route in routes:
#    route.click()
#    driver.switch_to.window(driver.window_handles[-1])
#    pageSource = driver.page_source
#    with open("page11.txt", "a", encoding="utf-8") as f:
#        f.write(pageSource)
#        f.close
#    driver.close()
#    driver.switch_to.window(driver.window_handles[0])  
#    
#    
## page 12
#
#page_12 = driver.find_element_by_xpath("//*[@data-page='12']")[0]
#page_12.click()
#time.sleep(2)
#
#routes = containers[1].find_elements_by_xpath('.//a')
#
#for route in routes:
#    route.click()
#    driver.switch_to.window(driver.window_handles[-1])
#    pageSource = driver.page_source
#    with open("page12.txt", "a", encoding="utf-8") as f:
#        f.write(pageSource)
#        f.close
#    driver.close()
#    driver.switch_to.window(driver.window_handles[0])       

    
    
driver.quit()
# Out:
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if __name__ == '__main__':
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\selenium\webdriver\remote\webelement.py:426: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:64: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:83: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:101: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:119: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:137: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# 6 clicked
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:142: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# start of 7
# clicked?
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:160: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:163: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:167: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# C:\Users\mertt\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:186: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
